# %%
my_list = [1, 2, 3]
print(my_list)
# Out:
# [1, 2, 3]

# %%
my_list = ['one','two','three', 4, 5]

# %%
my_list = ['A string', 23, 100.232, 'o']

# %%
my_list[0]
# Out:
# 'A string'

# %%
my_list[:3]
# Out:
# ['A string', 23, 100.232]

# %%
my_list = my_list + ['new item']

# %%
my_list
# Out:
# ['A string', 23, 100.232, 'o', 'new item']

# %%
my_list * 3
# Out:
# ['A string',
#  23,
#  100.232,
#  'o',
#  'new item',
#  'A string',
#  23,
#  100.232,
#  'o',
#  'new item',
#  'A string',
#  23,
#  100.232,
#  'o',
#  'new item']

# %%
list1 = [1, 2, 3]

# %%
list1.append('append me!')

# %%
list1
# Out:
# [2, 3, 'append me!']

# %%
list1.pop(0)
# Out:
# 1

# %%
popped_item = list1.pop()

# %%
popped_item
# Out:
# 'append me!'

# %%
new_list = ['a','e','x','b','c']

# %%
new_list.reverse()

# %%
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
# Let's make three lists

lst_1=[1,2,3]

lst_2=[4,5,6]

lst_3=[7,8,9]

# Make a list of lists to form a matrix

matrix = [lst_1,lst_2,lst_3]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[0][0]
# Out:
# 1

# %%
vaisiai = ["obuolys", "bananas", "kriause"]
print(vaisiai)
# Out:
# ['obuolys', 'bananas', 'kriause']

# %%
vaisiai.append('apelsinai')
vaisiai
# Out:
# ['obuolys', 'bananas', 'kriause', 'apelsinai']

# %%
vaisiai.insert(1,'citrina')
vaisiai
# Out:
# ['obuolys', 'citrina', 'bananas', 'kriause', 'apelsinai']

# %%
vaisiai.extend(["vynuoge", "persikas"])
print(vaisiai)  # Prideda kelis
# Out:
# ['obuolys', 'citrina', 'bananas', 'kriause', 'apelsinai', 'vynuoge', 'persikas']

# %%
vaisiai.remove('bananas')
vaisiai
# Out:
# ['obuolys', 'citrina', 'kriause', 'apelsinai', 'vynuoge', 'persikas']

# %%
vaisiai.pop()
vaisiai
# Out:
# ['obuolys', 'citrina', 'kriause', 'apelsinai', 'vynuoge']

# %%
print(vaisiai[0])
# Out:
# obuolys
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
vaisiai[1] = 'kivis'
print(vaisiai)
# Out:
# ['obuolys', 'kivis', 'kriause', 'apelsinai', 'vynuoge']

# %%
print(vaisiai.index('vynuoge'))
# Out:
# 4

# %%
vaisiai.sort()
vaisiai
# Out:
# ['apelsinai', 'kivis', 'kriause', 'obuolys', 'vynuoge']

# %%
vaisiai.reverse()
vaisiai
# Out:
# ['vynuoge', 'obuolys', 'kriause', 'kivis', 'apelsinai']

# %%
vaisiai.clear()
vaisiai
# Out:
# []

# %% [markdown]
# DICTIONARIES

# %%
# Make a dictionary with {} and : to signify a key and a value
my_dict = {'key1':'value1','key2':'value2'}

# %%
my_dict['key2']
# Out:
# 'value2'

# %%
my_dict = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}

# %%
my_dict['key3'][0]
# Out:
# 'item0'

# %%
my_dict['key3'][0].upper()
# Out:
# 'ITEM0'

# %%
my_dict['key1']
# Out:
# 123

# %%
my_dict['key1'] = my_dict['key1'] - 123
my_dict
# Out:
# {'key1': -246, 'key2': [12, 23, 33], 'key3': ['item0', 'item1', 'item2']}

# %%
d = {}

# %%
d['anaima'] = 'dog'

# %%
d['answer'] = 42

# %%
d
# Out:
# {'anaima': 'dog', 'answer': 42}

# %% [markdown]
# Nesting with Disctionaries

# %%
# Dictionary nested inside a dictionary nested inside a dictionary
d = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %%
# keep calling the keys
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %% [markdown]
# A few Disctionarie Methods

# %%
# Create a typical dictionary
d = {'key1':1,'key2':2,'key3':3}

# %%
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
d.values()
# Out:
# dict_values([1, 2, 3])

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])

# %%
asmuo = {
    "vardas": "Jonas",
    "amzius": 30,
    "miestas": "Vilnius"
}
print(asmuo)
# Out:
# {'vardas': 'Jonas', 'amzius': 30, 'miestas': 'Vilnius'}

# %%
print(asmuo['vardas'])
print(asmuo.get('amzius'))
# Out:
# Jonas
# 30

# %%
asmuo["amzius"] = 31
asmuo["el_pastas"] = "jonas@example.com"
print(asmuo)
# Out:
# {'vardas': 'Jonas', 'amzius': 31, 'miestas': 'Vilnius', 'el_pastas': 'jonas@example.com'}

# %%
print(asmuo.keys())
print(asmuo.values())
print(asmuo.items())
# Out:
# dict_keys(['vardas', 'amzius', 'miestas', 'el_pastas'])
# dict_values(['Jonas', 31, 'Vilnius', 'jonas@example.com'])
# dict_items([('vardas', 'Jonas'), ('amzius', 31), ('miestas', 'Vilnius'), ('el_pastas', 'jonas@example.com')])

# %%
asmuo.pop('miestas')
print(asmuo)
# Out:
# {'vardas': 'Jonas', 'amzius': 31, 'el_pastas': 'jonas@example.com'}

# %%
print("vardas" in asmuo)
print("miestas" in asmuo)
# Out:
# True
# False

# %%
# KPI pavyzdys: reikšmės pagal pavadinimą
kpi = {
    "revenue": 12500.50,
    "orders": 320,
    "return_rate": 0.035
}
kpi
# Out:
# {'revenue': 12500.5, 'orders': 320, 'return_rate': 0.035}

# %%
kpi.get('orders')
# Out:
# 320

# %%
kpi.get('profit') # neegzistuoja

# %%
transactions = [
    {"region": "LT", "amount": 120.0},
    {"region": "LT", "amount": 80.0},
    {"region": "EE", "amount": 55.0},
    {"region": "LV", "amount": 200.0},
    {"region": "LT", "amount": 40.0},
]
 
sales_by_region = {}
 
for t in transactions:
    region = t["region"]
    amount = t["amount"]
    sales_by_region[region] = sales_by_region.get(region, 0) + amount
 
sales_by_region
# Out:
# {'LT': 240.0, 'EE': 55.0, 'LV': 200.0}

# %%
products = {
    "SKU-001": {"name": "Kėdė", "price": 49.99, "stock": 120, "category": "Baldai"},
    "SKU-002": {"name": "Stalas", "price": 149.00, "stock": 35, "category": "Baldai"},
    "SKU-005": {"name": "Lempa", "price": 19.90, "stock": 7, "category": "Apšvietimas"},
}
products
# Out:
# {'SKU-001': {'name': 'Kėdė',
#   'price': 49.99,
#   'stock': 120,
#   'category': 'Baldai'},
#  'SKU-002': {'name': 'Stalas',
#   'price': 149.0,
#   'stock': 35,
#   'category': 'Baldai'},
#  'SKU-005': {'name': 'Lempa',
#   'price': 19.9,
#   'stock': 7,
#   'category': 'Apšvietimas'}}

# %%
sku = "SKU-002"
product_name = products[sku]["name"]
product_stock = products[sku]["stock"]
product_name, product_stock
# Out:
# ('Stalas', 35)

# %%
low_stock_threshold = 10
 
for sku, info in products.items():
    if info["stock"] < low_stock_threshold:
        print("Mažas likutis:", sku, info["name"], "likutis:", info["stock"])
# Out:
# Mažas likutis: SKU-005 Lempa likutis: 7
