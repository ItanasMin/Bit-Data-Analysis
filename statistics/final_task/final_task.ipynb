# %% [markdown]
# # Sales and Customer Behavior Analysis

# %% [markdown]
# ## Project Goal
#
# Apply core data analysis, statistics, and modeling methods by
# performing a full analysis cycle: from data understanding to statistical conclusions and
# forecasting in a Python environment.

# %% [markdown]
# ## Dataset
#
# **Supermarket Sales Dataset (Kaggle)**
#
# https://www.kaggle.com/datasets/faresashraf1001/supermarket-sales

# %% [markdown]
# ## Technical requirements
#
# - The analytical work must be submitted in **Jupyter Notebook** format (.ipynb) and
#   analytical conclusions as PDF or Word.
# - The code must be clean and consistent;
# - All results must be explained in text;
# - Emphasis is placed on clarity, correct logic, and business value.

# %% [markdown]
# ## Analysis stages

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Data understanding and preparation
#
# **Required:**
#
# - load the dataset;
# - briefly describe the data and variables;
# - check the data structure (size, columns, data types);
# - assess whether there are missing values or obvious data issues.
#
# **Result:** a short textual description and basic data overview.

# %% [markdown]
# ### Solution:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Descriptive analysis (or Exploratory Data Analysis - EDA)
#
# **Required:**
#
# - calculate main statistical metrics for at least one numeric variable:
#   - mean,
#   - median,
#   - standard deviation,
#   - minimum and maximum;
# - present at least 3-5 clear plots (e.g., sales distribution, sales by city or product
#   line);
# - briefly explain what these results show.

# %% [markdown]
# ### Solution:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Confidence intervals
#
# **Required:**
#
# - select one numeric variable (e.g., Total, gross income, or Rating);
# - calculate a 95% confidence interval for its mean;
# - explain how to interpret this interval in a practical context.

# %% [markdown]
# ### Solution:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Hypothesis testing
#
# At least **one** statistical hypothesis test must be performed.
#
# **Possible examples:**
#
# - t-test: comparison of average purchase amount between Customer type (Member vs
#   Normal);
# - ANOVA: comparison of average sales or revenue across Branch.

# %% [markdown]
# ### Solution:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Analytical part

# %% [markdown]
# #### A. Regression analysis
#
# - choose a target variable (e.g., Total);
# - build a regression model;
# - evaluate model quality (e.g., R², MAE, or RMSE);
# - briefly interpret the results.

# %% [markdown]
# ### Solution:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### B. Time series analysis
#
# - aggregate sales over time (days or months);
# - visualize sales dynamics;
# - describe observed trends or seasonality;
# - provide a simple forecasting exa

# %% [markdown]
# ### Solution:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Conclusions
#
# **Required:**
#
# - summarize the main analysis results;
# - explain how these insights may be useful for the business;
# - provide clear and concise conclusions/documentation in PDF or Word (1-3 pages).

# %% [markdown]
# ### Solution:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---
