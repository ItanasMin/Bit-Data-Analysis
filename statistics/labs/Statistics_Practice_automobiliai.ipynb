# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# Įsikelkite duomenis

# %%
df = pd.read_csv(r"C:\Users\Itanas\Desktop\Bit-Data-Analysis\statistics\data/automobiliai.csv")
df.head()
# Out:
#    kuro_sanaudos  cilindrai  arklio_galios  svoris  isibegejimas  \
# 0           18.0          8            130    3504          12.0
# 1           15.0          8            165    3693          11.5
# 2           18.0          8            150    3436          11.0
# 3           16.0          8            150    3433          12.0
# 4           17.0          8            140    3449          10.5
#
#    gamybos_metai                pavadinimas
# 0             70  chevrolet chevelle malibu
# 1             70          buick skylark 320
# 2             70         plymouth satellite
# 3             70              amc rebel sst
# 4             70                ford torino

# %% [markdown]
# Apskaičiuokite pagrindinę aprašomąją statistiką

# %%
df.describe().round(2)
# Out:
#        kuro_sanaudos  cilindrai  arklio_galios   svoris  isibegejimas  \
# count         392.00     392.00         392.00   392.00        392.00
# mean           23.45       5.47         104.47  2977.58         15.54
# std             7.81       1.71          38.49   849.40          2.76
# min             9.00       3.00          46.00  1613.00          8.00
# 25%            17.00       4.00          75.00  2225.25         13.78
# 50%            22.75       4.00          93.50  2803.50         15.50
# 75%            29.00       8.00         126.00  3614.75         17.02
# max            46.60       8.00         230.00  5140.00         24.80
#
#        gamybos_metai
# count         392.00
# mean           75.98
# std             3.68
# min            70.00
# 25%            73.00
# 50%            76.00
# 75%            79.00
# max            82.00

# %% [markdown]
# Kaip pasiskirsčiusios kuro sąnaudos? pavaizduokite grafiškai

# %%
plt.figure(figsize=(10, 6))
ax = sns.histplot(df["kuro_sanaudos"], kde=True, color="green", bins=20)

mean_val = df["kuro_sanaudos"].mean()
median_val = df["kuro_sanaudos"].median()

plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color = 'orange', linestyle = '-.', label=f'Median: {median_val:.2f}')

plt.title('Fuel Consumption')
plt.xlabel('Fuel consumption (l/100km)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# Kaip pasiskirsčiusios Arklio galios? pavaizduokite grafiškai

# %%
plt.figure(figsize=(10, 6))
ax = sns.histplot(df["arklio_galios"], kde=True, color="blue", bins=20)

mean_val = df["arklio_galios"].mean()
median_val = df["arklio_galios"].median()

plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f} HP')
plt.axvline(median_val, color='orange', linestyle='-.', label=f'Median: {median_val:.2f} HP')

plt.title('Horsepower Distribution')
plt.xlabel('Horsepower (HP)')
plt.ylabel('Number of engines')
plt.legend()
plt.show()

# %% [markdown]
# Koks vidutinis automobilių svoris?

# %%
df.head()
# Out:
#    kuro_sanaudos  cilindrai  arklio_galios  svoris  isibegejimas  \
# 0           18.0          8            130    3504          12.0
# 1           15.0          8            165    3693          11.5
# 2           18.0          8            150    3436          11.0
# 3           16.0          8            150    3433          12.0
# 4           17.0          8            140    3449          10.5
#
#    gamybos_metai                pavadinimas
# 0             70  chevrolet chevelle malibu
# 1             70          buick skylark 320
# 2             70         plymouth satellite
# 3             70              amc rebel sst
# 4             70                ford torino

# %%
mean_weight = df['svoris'].mean()
print(f"Vidutinis automobilių svoris yra: {mean_weight:,.2f}")
# Out:
# Vidutinis automobilių svoris yra: 2,977.58

# %% [markdown]
# Apskaičiuokite koreliacijos matricą

# %% [markdown]
# Nubraižykite koreliacijos matricos šilumos žemėlapį

# %% [markdown]
# Ar yra ryšis tarp kintamųjų? ar galite apibūdinti koks?

# %% [markdown]
# Nubraižykite svorio ir kuro sąnaudų sklaidos grafiką

# %% [markdown]
# Nubraižykite arklio galių ir kuro sąnaudų sklaidos grafiką

# %% [markdown]
# Ar yra reikšmingas kuro sąnaudų skirtumas tarp automobilių su 4 ir 8 cilindrais

# %% [markdown]
# Apskaičiuokite pasikliautinąjį intervalą vidutinėms kuro sąnaudoms su 95% reikšmingumo lygiu

# %% [markdown]
# Apskaičiuokite pasikliautinąjį intervalą vidutiniam svoriu su 99% reikšmingumo lygiu
